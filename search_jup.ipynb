# %%
#!/usr/bin/env python
# coding: utf-8

import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import re

# initializing lists with information about job
jobs_content = []  # list with page content about job
jobs_names = []  # list with names of the jobs
jobs_links = []  # list with links to the job page
all_jobs_links = [] # list of all jobs links

# job we want to take
job = 'Веб-разработчик'

# going through all pages at hh.ru site and collecting links that
# refer to job variable and also get content from them
for page_number in range(2):
    # creating link for our job and current page
    jobs_page = 'https://spb.hh.ru/search/vacancy?area=2&st=searchVacancy&text=' + job.lower() + '&page=' + str(
        page_number)

    # getting current hh.ru page with our job
    page = requests.get(jobs_page, headers={'User-Agent': 'Custom'})
    
    # clearing jobs links list
    jobs_links.clear()

    # cheking if page is ready to
    # bring us some data, else getting error code
    if page.status_code == 200:
        # parsing page using Beautiful soup
        soup = BeautifulSoup(page.text, 'html.parser')

        # forming vacancies list from link that
        # refer to partucular vacancy
        vacancies_list = soup.find_all('a', {'class': 'bloko-link HH-LinkModifier'})

        # cheking if vacancies list is not empty
        # and if so, getting vacancy name
        # and vacancy link, then retrieve data from vacancy page
        if len(vacancies_list) > 0:
            # collecting links and names of vacancies
            for vacancy in vacancies_list:
                jobs_names.append(vacancy.text)
                if vacancy['href']:
                    jobs_links.append(vacancy['href'])
                    all_jobs_links.append(vacancy['href'])
                else:
                    print('No job link')
                    jobs_links.append(None)

            # getting page content for each vacancy
            for link in jobs_links:
                # getting vacancy page
                job_page = requests.get(link, headers={'User-Agent': 'Custom'})

                # checking if page is ready to
                # bring us some data, else getting error code
                if job_page.status_code == 200:
                    # parsing vacancy page using Beautiful Soup
                    job_soup = BeautifulSoup(job_page.text, 'html.parser')

                    # getting vacancy page content
                    page_content = job_soup.find('div', {'class': 'g-user-content'})

                    # forming jobs content list
                    jobs_content.append(page_content)
                else:
                    print("Something wrong with the page: ", job_page.status_code)
                    print('vacancy problem')
        else:
            print('No items in vacancies_list')
    else:
        print('Something wrong with page: ', page.status_code)
        print('GEneral page problem')

# initializing list with all data about vacancies
data_list = []

# going through jobs contents and splitting it
# by <strong>. So we get all important headings
# and will be able to get requesments, conditions
# and responsibilities
for job_content in jobs_content:
    data_list.append(re.split('<strong>', str(job_content).lower()))

# initializing lists with information about vacancy
jobs_treb = []  # list of vacancy requerments
jobs_usl = []  # list of vancy conditions
jobs_obyaz = []  # list of vacancy responsibilities
jobs_desc = []  # list of vacancy desctiption

# going through splitted data and getting
# requerments, conditions, responsibilities
# and descriptions
for job in data_list:
    # getting descriptiong because
    # it is always first in the split
    jobs_desc.append(job[0])

    # initializing flags witch note if there is
    # one of requesments, conditions and responsibilities
    # in the split
    treb_flag = False
    obyaz_flag = False
    usl_flag = False

    # checking if there is one of three conditions
    # in our split and if so, adding this conditions
    # to corresponding lists
    for job_content in job:
        if job_content.startswith('требования'):
            jobs_treb.append(job_content)
            treb_flag = True

        if job_content.startswith('обязанности'):
            jobs_obyaz.append(job_content)
            obyaz_flag = True

        if job_content.startswith('условия'):
            jobs_usl.append(job_content)
            usl_flag = True

    # if we haven't found any conditions
    # we add None item to corresponding list
    if treb_flag == False:
        jobs_treb.append(None)

    if obyaz_flag == False:
        jobs_obyaz.append(None)

    if usl_flag == False:
        jobs_usl.append(None)

# initializing lists with clean data about requerments, conditions
# and responsibilities
new_jobs_treb = []  # list of vacancy requerments
new_jobs_obyaz = []  # list of vacancy responsibilities
new_jobs_usl = []  # list of vacancy conditions


# Cleaning informations funcition
# Arguments:
#  Data we want to clean and list where we want
# .  to put this data
# . (data, data_list)
#  Returns:
# .  None
def clear_data(data, data_list):
    # going through the data and firstly cleaning
    # out of three possible conditions, then split
    # out data by html tags to form list or conditions
    # and cleanign data out of usless symbols
    for elem in data:
        if elem != None:
            # cleaning of three conditions
            item = re.sub('требования', '', elem)
            item2 = re.sub('к кандидату', '', item)
            item3 = re.sub('к кандидатам', '', item2)
            item4 = re.sub('условия', '', item3)
            item5 = re.sub('обязанности', '', item4)

            # splitting by html tags
            splited_items = re.split(r'<.*?>', item5)

            # initializing list with clean items
            cleared_items = []

            # going through splitted items, cleaning
            # them and adding to cleared items list
            for item in splited_items:
                cleared_items.append(re.sub(r'[^\w\d\s]+', '', re.sub(r'\s+', ' ', re.sub(r'<.*?>', '', item))))

            # deleating all empty items
            while ("" in cleared_items):
                cleared_items.remove("")

            # deleating all space items
            while (" " in cleared_items):
                cleared_items.remove(" ")

            # adding cleaned items to data_list
            data_list.append(cleared_items)
        else:
            # if no element in data, adding None
            data_list.append(None)


# claning information
clear_data(jobs_obyaz, new_jobs_obyaz)
clear_data(jobs_usl, new_jobs_usl)
clear_data(jobs_treb, new_jobs_treb)

# initializing list for cleaned
# description data
new_jobs_desc = []

# going through all descriptions
# and cleaning it
for desc in jobs_desc:
    # if something in descriotion, cleaning
    # it, overwise, adding None
    if desc != None:
        item = re.sub(r'[^\w\d\s]+', '', re.sub(r'\s+', ' ', re.sub(r'<.*?>', '', desc)))
        new_jobs_desc.append(item)
    else:
        new_jobs_desc.append(None)

# forming DataFrame from retrieved data
web_data = pd.DataFrame({'description': new_jobs_desc, 'requerments': new_jobs_treb, 'conditions': new_jobs_usl,
                         'responsibilities': new_jobs_obyaz, 'links': all_jobs_links})

# initializing lists of courses information
courses_links = []  # list of courses links
courses_skills = []  # list of courses skills
page_links = [] # links to cources on current page

# going through all pages of current job we want to take
# and getting information about skilles we want to aquire
for page in range(1, 13):
    # forming link to courcera pages with job courses we want
    courses_link = 'https://www.coursera.org/search?query=web%20development&indices%5Bprod_all_products_term_optimization%5D%5Bpage%5D=' + str(
        page) + '&indices%5Bprod_all_products_term_optimization%5D%5Bconfigure%5D%5BclickAnalytics%5D=true&indices%5Bprod_all_products_term_optimization%5D%5Bconfigure%5D%5BruleContexts%5D%5B0%5D=ru&indices%5Bprod_all_products_term_optimization%5D%5Bconfigure%5D%5BhitsPerPage%5D=10&configure%5BclickAnalytics%5D=true'

    # getting current page
    page = requests.get(courses_link, headers={'User-Agent': 'Custom'})

    # cheking if page is ready to
    # bring us some data, else getting error code
    if page.status_code == 200:
        # parsing page using Beautiful Soup
        soup = BeautifulSoup(page.text, 'html.parser')

        # getting all courses links at current page
        courses_list = soup.find_all('a', {'data-click-key': 'search.search.click.search_card'})

        # checking if there are courses link on
        # the page and if so, adding links to links list
        # getting course page and retrieving skilles
        if len(courses_list) > 0:
            # clearing page links list
            page_links.clear()
            
            # going through courses and forming links
            for course in courses_list:
                # adding links to links list
                courses_links.append('https://www.coursera.org' + course['href'])
                page_links.append('https://www.coursera.org' + course['href'])

            # going through links and getting pages and skilles
            for link in page_links:
                # getting course page
                course_page = requests.get(link, headers={'User-Agent': 'Custom'})

                # cheking if page is ready to
                # bring us some data, else getting error code
                if course_page.status_code == 200:
                    # parsing page using Beautiful Soup
                    course_soup = BeautifulSoup(course_page.text, 'html.parser')

                    # getting all acquired skilles from course page
                    acquired_skilles = course_soup.find_all('div', {'class': 'Skills border-a p-x-2 p-t-1 p-b-2 m-y-2'})
                    # adding skilles to skilles list
                    courses_skills.append(acquired_skilles)
                else:
                    print("Something wrong with page: ", course_page.status_code)
                    courses_skills.append(None)
                    print('Single cource problem')

        else:
            print('No items in courses_list')
    else:
        print('Something wrong with page: ', page.status_code)
        print('General cource problem')

# initializing list of cleaned courses skilles
new_courses_skilles = []

# going through all courses skills and
# forming list of skills for each course
for course in courses_skills:
    # checking if something in courses list
    # and if so, getting it
    if course != None and len(course) > 0:
        # initializing list with skills
        # for current cource
        temp_skilles = []

        # getting all skilles for current course
        # forming temp_skilles list and adding it
        # to new_courses_skilles
        for skill in range(len(course[0].find_all('span', {'class': 'centerContent_dqfu5r'}))):
            temp_skilles.append(course[0].find_all('span', {'class': 'centerContent_dqfu5r'})[skill].text)
        new_courses_skilles.append(temp_skilles)
    else:
        new_courses_skilles.append(None)
# Out:
# Something wrong with page:  404
# Single cource problem
# Something wrong with page:  404
# Single cource problem
# Something wrong with page:  404
# Single cource problem
# Something wrong with page:  404
# Single cource problem
# Something wrong with page:  404
# Single cource problem
# Something wrong with page:  404
# Single cource problem

# %%
# getting data where requerments are not null
web_data_with_full_req = web_data[web_data['requerments'].notnull()]

# %%
# setting to display all records in jupyter notebook
# with a scrollbar
pd.set_option('display.max_columns', 150)
pd.set_option('display.width', 1000)
web_data_with_full_req
# Out:
#                                           description                                        requerments                                         conditions                                   responsibilities                                              links
# 5                                                      [опыт работы от 3х лет работы webразработчиком...  [срочный трудовой договор до 31122020г, оформл...  [поддержка работоспособности существующих сайт...  https://spb.hh.ru/vacancy/35271493?query=%D0%B...
# 6   angels it  компания разработчик комплексных ec...  [знания php mysqlmariadb html css javascript j...  [уютный офис на 34 человека в 7 минутах пешком...                                               None  https://spb.hh.ru/vacancy/35271499?query=%D0%B...
# 7   мы ищем full stack разработчика на наш новый п...  [высшее техническое образование, опыт разработ...                                               None  [разработка серверного программного обеспечени...  https://spb.hh.ru/vacancy/35554864?query=%D0%B...
# 9   наша компания инвестирует в собственные интерн...  [ хорошие знания html5 css3 jsjquery как миним...  [ никакого общения с клиентами,  своевременные...  [ вёрстка страниц для сайтов на основе psd мак...  https://spb.hh.ru/vacancy/35208588?query=%D0%B...
# 98                                                     [хорошие навыки html5 css3 javascript jquery, ...  [5дневная рабочая неделя 10001900 пт 1800 обед...  [интеграция верстка с cms, верстка посадочных ...  https://spb.hh.ru/vacancy/35448295?query=%D0%B...

# %%
# forming cources data with skilles and link to cources
cources_data = pd.DataFrame({'skilles': new_courses_skilles, 'links': courses_links})

# getting data where skills are not null
cources_data_without_nones = cources_data[cources_data['skilles'].notnull()]

# %%
# Out:
# ['Web Development',
#  'Cascading Style Sheets (CCS)',
#  'Html5',
#  'JavaScript',
#  'Responsive Web Design']

# %%
# Out:
# 'php 7 '

# %%
# initializing list for new requerments
new_requerments = []

# going through old requerments and extracting
# only valuable information
for req in web_data_with_full_req['requerments']:
    # initializing temproary requerments list
    temp_req = []
    
    # going through single requerment and cleaning it
    for string in req:
        # cleaning requerments
        new_string = re.sub(r'[1-9]+', '', re.sub('ё', '', re.sub(r'\s+', ' ', re.sub(r'[а-я]+', '', string))))
        new_s = re.sub(r'\s+', ' ', new_string)
        
        # adding single requerment to temproary lsit
        temp_req.append(new_s)
    
    # adding temproary requerments list to 
    # new requerments list
    new_requerments.append(temp_req)

# deleating all space items
for item in new_requerments:
    while (" " in item):
        item.remove(" ")

# %%
# initializing requerments list
# where all key words are splitted
update_requerments = []

# going through all requerments and
# splitting them by space
for req in new_requerments:
    # initializing temproary list for single string
    temp = []
    
    # going through single string and splitting it
    # by space
    for i in req:
        splited_req = i.split()
        
        # adding splitted requerments to temp list
        temp.append(splited_req)
    
    # adding splitted items to updated requerments list
    update_requerments.append(temp)

# %%
update_requerments
# Out:
# [[['javascriptnodejs'], ['html', 'css'], ['svn', 'git']],
#  [['html', 'css', 'jsjquery', 'lesssass'],
#   ['stylus'],
#   ['wordpress'],
#   ['bem'],
#   ['gulp']],
#  [['html', 'css', 'jquery', 'php', 'mysql'],
#   ['perfect', 'pixel'],
#   ['cms', 'opencart', 'wordpress', 'webasyst']],
#  [['php'],
#   ['ms', 'sql', 'server', '0'],
#   ['freebsdlinux'],
#   ['javascript'],
#   ['sencha'],
#   ['reactjs'],
#   ['spa'],
#   ['npm', 'git', 'webpack', 'html', 'css'],
#   ['nodejs']],
#  [['php'],
#   ['mysqlx'],
#   ['javascript', 'jquery'],
#   ['htmlcss'],
#   ['svn', 'git'],
#   ['xml', 'php', 'soap', 'rest'],
#   ['npm', 'composer'],
#   ['unit', 'phpunit', 'codeception'],
#   ['mongodb', 'redis', 'elastic', 'search']],
#  [['cms', 'wordpress'], ['php', 'html', 'css', 'js'], ['git']],
#  [['php'], ['sql', 'mysql'], ['jscsshtml']],
#  [['frontend'],
#   ['javascript', 'es'],
#   ['css'],
#   ['frontend', 'reactangularvue'],
#   ['backend'],
#   ['net', 'core', 'net', 'framework']],
#  [['php', 'mysql'], ['csshtml', 'js'], ['http']],
#  [['html', 'css'],
#   ['cms', 'joomla', 'bitrix', 'umi', 'wordpress'],
#   ['php', 'javascript', 'jquery', 'mysql'],
#   ['adobe', 'photoshop', 'figma']],
#  [['frontend', 'spa', 'single', 'page', 'application'],
#   ['javascript', 'html', 'css'],
#   ['photoshop', 'figma'],
#   ['js', 'vuejs', 'vuex', 'react', 'angular'],
#   ['http', 'websocket', 'rest', 'api', 'mysql', 'php'],
#   ['cms', 'git', 'bitbucket'],
#   ['cms', 'joomla', 'wordpress', 'drupal', 'dle', 'cms', 'opencart', 'cms']],
#  [['php', 'gt'],
#   ['yii'],
#   ['mysql', 'having', 'join'],
#   ['memcached', 'redis'],
#   ['html', 'css', 'js'],
#   ['bootstrap', 'jquery'],
#   ['sass', 'webpack', 'gulp'],
#   ['vuejs', 'nuxtjs'],
#   ['unix'],
#   ['nginx'],
#   ['unit'],
#   ['git'],
#   ['docker'],
#   ['jira'],
#   ['confluence']],
#  [['backend'],
#   ['modx', 'revolution'],
#   ['modx'],
#   ['php'],
#   ['mvc'],
#   [],
#   ['curl', 'json'],
#   ['mysql'],
#   ['join'],
#   ['redis', 'cron'],
#   ['frontend'],
#   ['html', 'css'],
#   ['bootstrap', 'grid'],
#   ['javascript'],
#   ['jquery', 'ajax'],
#   ['api'],
#   ['laravel', 'symfony', 'yii']],
#  [['web']],
#  [['web'], ['cms', 'bitrix', 'css', 'js', 'html', 'json']],
#  [['php', 'mysqlmariadb', 'html', 'css', 'javascript', 'jquery'], ['git']],
#  [['php'], ['joomla'], ['vuejs']],
#  [['frontend', 'react', 'redux'], ['javascript'], ['mysql']],
#  [['phpjavascript'], ['bootstrap', 'jquery']],
#  [['web', 'frontend'],
#   ['javascript', 'eses', 'typescript'],
#   ['html', 'css', 'sass'],
#   ['spa', 'framework', 'vuegsvuex'],
#   ['webpack'],
#   ['backend', 'api'],
#   ['git']],
#  [['php', 'yii', 'laravel'],
#   ['javascript', 'jquery', 'mysql', 'left', 'join', 'html', 'css'],
#   ['linux'],
#   ['git', 'jira']],
#  [['cms'],
#   ['api', 'd', 'orm'],
#   ['result_modifier', 'component_epilog'],
#   ['php', 'x', 'mysql', 'html', 'css', 'js', 'jquery', 'ajax'],
#   ['git']],
#  [['magento'],
#   ['php', 'mysql', 'apache', 'nginx', 'javascript', 'html', 'css', 'xml'],
#   ['nix'],
#   ['adobe', 'photoshop']],
#  [['java', 'core'], ['javascript'], ['cssless'], ['unit']],
#  [['php'],
#   ['laravel'],
#   ['sql', 'mysql'],
#   ['jscsshtml'],
#   ['git', 'gitflow'],
#   ['unixlinux', 'bash']],
#  [['php', 'html', 'css', 'js', 'javascript', 'vcs'], ['cms', 'bitrix']],
#  [['javascript'],
#   ['python', 'x'],
#   ['nodejs'],
#   ['jquery'],
#   ['vuejs'],
#   ['angular'],
#   ['angularjs'],
#   ['html'],
#   ['css'],
#   ['git'],
#   ['webpack'],
#   ['babel'],
#   ['socket', 'io'],
#   ['mysql'],
#   ['sqlite']],
#  [],
#  [['python'], ['flask', 'django'], ['unittest', 'pytest'], ['sql']],
#  [],
#  [['web'],
#   ['php', 'x'],
#   ['symfony', 'yii', 'laravel'],
#   ['yii'],
#   ['mysql', 'postgresql'],
#   ['unit'],
#   ['cicd']],
#  [['php'],
#   ['javascript'],
#   ['git'],
#   ['html', 'css', 'sass'],
#   ['php', 'framework', 'yii'],
#   ['docker'],
#   ['cms']],
#  [['html', 'css'], ['http', 'ftp', 'ssh'], ['js'], ['php']],
#  [['c', 'net'],
#   ['entity', 'frameworkadonet'],
#   ['drydiekisssolidyagni'],
#   ['ms', 'sql', 'tsql']],
#  [['php', 'laravel', 'yii', 'mysql', 'nodejs', 'react', 'vue', 'git', 'nginx'],
#   ['full', 'front', 'back']],
#  [['html', 'css', 'javascript'], ['php'], ['cms', 'wordpress']],
#  [['python'],
#   ['django', 'celery', 'flask'],
#   ['postgresql'],
#   ['swagger', 'django', 'orm'],
#   ['nginx'],
#   ['git'],
#   ['linux'],
#   ['frontend']],
#  [['d', 'orm'], ['html', 'js', 'jquery', 'ajax'], ['linux']],
#  [['php'],
#   ['laravel'],
#   ['mysql'],
#   ['javascript', 'es', 'jquery', 'vuejs'],
#   ['git'],
#   ['html', 'css', 'sass'],
#   ['docker']],
#  [['laravel'],
#   ['php', 'javascript', 'html', 'css', 'mysql'],
#   ['google', 'tagmanager']],
#  [['phpjava'],
#   ['orm', 'mvc', 'soa'],
#   ['postgresqlmysqlfirebird'],
#   ['http', 'rest', 'api'],
#   ['htmlcssjavascriptajaxjqueryangularyiinodejssql']],
#  [['nodejs'], ['backend'], ['devops']],
#  [[],
#   ['javascript', 'es', 'es'],
#   ['html', 'css'],
#   ['nodejs'],
#   ['vuejs', 'react', 'angular'],
#   ['webpack', 'babel'],
#   ['web', 'api', 'soap', 'rest', 'websocket', 'api'],
#   ['git', 'svn'],
#   ['mvc', 'design', 'patterns'],
#   ['typescript', 'less', 'scss', 'sass'],
#   ['module',
#    'bundlers',
#    'webpack',
#    'parcel',
#    'browserify',
#    'rollup',
#    'fusebox'],
#   ['npm', 'yarn'],
#   ['builders', 'and', 'task', 'runners', 'grunt', 'gulp'],
#   ['virtualbox', 'vargant', 'docker'],
#   ['c', 'mongodb', 'redis', 'cassandra', 'neoj'],
#   ['linux'],
#   ['ruby', 'python', 'java', 'bash', 'perl', 'php', 'cc'],
#   [],
#   []],
#  [['php', 'html', 'css', 'javascript', 'sql'], ['seo']],
#  [['html', 'css', 'javascript'],
#   ['sql', 'er', 'mysql'],
#   ['frontend', 'react', 'js'],
#   ['backend', 'python', 'amp', 'django', 'python'],
#   ['http', 'ssl', 'tls']],
#  [['html', 'css', 'javascript', 'jquery'],
#   ['css', 'sass', 'bem', 'class', 'names', 'gulp'],
#   ['php', 'mysql', 'ajax']],
#  [['javascript'],
#   ['spa', 'reactjs'],
#   ['svg', 'canvasd', 'webgl'],
#   ['http', 'json'],
#   ['js']],
#  [['php'],
#   ['symfony'],
#   ['mvc'],
#   ['git'],
#   ['js'],
#   ['web'],
#   ['web', 'react', 'angular']],
#  [['wordpress']]]

# %%
# updating vacancies list with cleaned requerments
web_data_with_full_req['cleaned requerments'] = update_requerments
# Out:
# /var/data/python/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 98                                                     [хорошие навыки html5 css3 javascript jquery, ...  [5дневная рабочая неделя 10001900 пт 1800 обед...  [интеграция верстка с cms, верстка посадочных ...  https://spb.hh.ru/vacancy/35448295?query=%D0%B...  [[html, css, javascript, jquery], [css, sass, ...

# %%
cources_data_without_nones
# Out:
#                                                skilles                                              links
# 0    [Web Development, Cascading Style Sheets (CCS)...  https://www.coursera.org/specializations/web-d...
# 1    [Bootstrap (Front-End Framework), Node.Js, Rea...  https://www.coursera.org/specializations/full-...
# 2    [Css Code, Html, JavaScript, Cascading Style S...     https://www.coursera.org/learn/web-development
# 3    [Html, JavaScript, Cascading Style Sheets (CCS...  https://www.coursera.org/learn/duke-programmin...
# 4        [HTML/CSS, Mongodb, Meteor, APIs, JavaScript]  https://www.coursera.org/specializations/websi...
# ..                                                 ...                                                ...
# 97   [Nativescript, Desarrollo Mobile Multiplatafor...  https://www.coursera.org/learn/aplicaciones-mo...
# 101  [Interaction Technique, List Of Graphical User...  https://www.coursera.org/learn/android-program...
# 107  [Opengl++, VR, Sensors, Android Studio, Textures]  https://www.coursera.org/learn/3d-graphics-and...
# 111        [Ruby On Rails, Angularjs, Web Development]  https://www.coursera.org/learn/photo-tourist-w...
# 119  [Html, JavaScript, Cascading Style Sheets (CCS...  https://www.coursera.org/specializations/java-...
#
# [66 rows x 2 columns]

# %%
# initializing list for web development key words
web_development_keywords = []

# going through requerments and forming keywords list
for cource_reqs in web_data_with_full_req['cleaned requerments']:
    for req in cource_reqs:
        for i in req:
            web_development_keywords.append(i)

# going through skilles and forming keywords list
for cource_skilles in cources_data_without_nones['skilles']:
    for skill in cource_skilles:
        temp_words = skill.split()
        for i in temp_words:
            web_development_keywords.append(i)
    
# initializing list for cleaned key words
new_web_development_keywords = []

# cleaning key words
for word in web_development_keywords:
    new_word = re.sub('\(', '', word)
    clered_word = re.sub('\)', '', new_word)
    clered_word = re.sub('[\+]+', '', clered_word)
    new_web_development_keywords.append(clered_word)
    
new_web_development_keywords

# %%
def get_cources(vacancy_link):
    # getting vacancy page
    job_page = requests.get(vacancy_link, headers={'User-Agent': 'Custom'})

    # checking if page is ready to
    # bring us some data, else getting error code
    if job_page.status_code == 200:
        # parsing vacancy page using Beautiful Soup
        job_soup = BeautifulSoup(job_page.text, 'html.parser')

        # getting vacancy page content
        page_content = job_soup.find('div', {'class': 'g-user-content'})
        
        # getting splitted page content
        splitted_page_content = re.split('<strong>', str(page_content).lower())

        # initializing flags witch note if 
        # requerments in split
        treb_flag = False
        
        # initializing jobs requerments list
        job_requerments = []
        
        # checking if requerments in the list
        for job_content in splitted_page_content:
            if job_content.startswith('требования'):
                job_requerments.append(job_content)
                treb_flag = True
            
        # if requerments in vacancy, we simply get them
        # and find suitable cources
        if treb_flag != False:
            print('YES')
            item = re.sub('требования', '', job_requerments[0])
            item2 = re.sub('к кандидату', '', item)
            item3 = re.sub('к кандидатам', '', item2)

            # splitting by html tags
            splited_items = re.split(r'<.*?>', item3)

            # initializing list with clean items
            cleared_items = []

            # going through splitted items, cleaning
            # them and adding to cleared items list
            for item in splited_items:
                cleared_items.append(re.sub(r'[^\w\d\s]+', '', re.sub(r'\s+', ' ', re.sub(r'<.*?>', '', item))))

            # deleating all empty items
            while ("" in cleared_items):
                cleared_items.remove("")

            # deleating all space items
            while (" " in cleared_items):
                cleared_items.remove(" ")

            print(cleared_items)
            
            # initializing list for new requerments
            new_req = []


            # initializing temproary requerments list
            temp_req = []

            # going through single requerment and cleaning it
            for string in cleared_items:
                # cleaning requerments
                new_string = re.sub(r'[1-9]+', '', re.sub('ё', '', re.sub(r'\s+', ' ', re.sub(r'[а-я]+', '', string))))
                new_s = re.sub(r'\s+', ' ', new_string)

                # adding single requerment to temproary lsit
                temp_req.append(new_s)

            # adding temproary requerments list to 
            # new requerments list
            new_req.append(temp_req)

            # deleating all space items
            for item in new_req:
                while (" " in item):
                    item.remove(" ")
                    
            # initializing list with cleared requrments
            cleared_reqs = []
                    
            for i in new_req[0]:
                temp_item = i.split()
                for j in temp_item:
                    cleared_reqs.append(j)
            
            print(cleared_reqs)
            
            # initializing cources list
            cources_list = []
            
            # going through requerments and finding cources
            for req in cleared_reqs:
                for (cources_skilles, link) in \
                    zip(cources_data_without_nones['skilles'], cources_data_without_nones['links']):
                    if re.search(req, (''.join(cources_skilles)).lower()):
                        cources_list.append(link)
            
            return cources_list
        
        else:
            print('No requerments')
            # clearing vacancy data
            cleared_content = re.sub(r'[^\w\d\s]+', '', re.sub(r'\s+', ' ', re.sub(r'<.*?>', '', str(splitted_page_content))))
            
            # key words set
            key_words = set()
            
            # getting possibles requerments
            for word in new_web_development_keywords:
                if re.search(word, cleared_content):
                    if len(word) < 3:
                        continue
                    else:
                        key_words.add(word)
                    
            print(key_words)
            
            # initializing cources list
            cources_list = []
            
            # going through requerments and finding cources
            for req in key_words:
                for (cources_skilles, link) in \
                    zip(cources_data_without_nones['skilles'], cources_data_without_nones['links']):
                    if re.search(req, (''.join(cources_skilles)).lower()):
                        cources_list.append(link)
            
            return cources_list
    else:
        print("Something wrong with the page: ", job_page.status_code)
        print('vacancy problem')

# %%
links = get_cources('https://spb.hh.ru/vacancy/35471010?query=%D0%B2%D0%B5%D0%B1%20%D1%80%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%87%D0%B8%D0%BA')

# %%
links

# %%
links2 = get_cources('https://spb.hh.ru/vacancy/35564260?query=%D0%B2%D0%B5%D0%B1%20%D1%80%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%87%D0%B8%D0%BA')

# %%
links2

# %%
# Out:
# ['web',
#  'cms',
#  'bitrix',
#  'css',
#  'js',
#  'html',
#  'json',
#  'php',
#  'mysqlmariadb',
#  'html',
#  'css',
#  'javascript',
#  'jquery',
#  'git',
#  'javascriptnodejs',
#  'html',
#  'css',
#  'svn',
#  'git',
#  'html',
#  'css',
#  'jsjquery',
#  'lesssass',
#  'stylus',
#  'wordpress',
#  'bem',
#  'gulp',
#  'html',
#  'css',
#  'jquery',
#  'php',
#  'mysql',
#  'perfect',
#  'pixel',
#  'cms',
#  'opencart',
#  'wordpress',
#  'webasyst',
#  'php',
#  'ms',
#  'sql',
#  'server',
#  '0',
#  'freebsdlinux',
#  'javascript',
#  'sencha',
#  'reactjs',
#  'spa',
#  'npm',
#  'git',
#  'webpack',
#  'html',
#  'css',
#  'nodejs',
#  'php',
#  'mysqlx',
#  'javascript',
#  'jquery',
#  'htmlcss',
#  'svn',
#  'git',
#  'xml',
#  'php',
#  'soap',
#  'rest',
#  'npm',
#  'composer',
#  'unit',
#  'phpunit',
#  'codeception',
#  'mongodb',
#  'redis',
#  'elastic',
#  'search',
#  'cms',
#  'wordpress',
#  'php',
#  'html',
#  'css',
#  'js',
#  'git',
#  'frontend',
#  'javascript',
#  'es',
#  'css',
#  'frontend',
#  'reactangularvue',
#  'backend',
#  'net',
#  'core',
#  'net',
#  'framework',
#  'php',
#  'sql',
#  'mysql',
#  'jscsshtml',
#  'php',
#  'mysql',
#  'csshtml',
#  'js',
#  'http',
#  'html',
#  'css',
#  'cms',
#  'joomla',
#  'bitrix',
#  'umi',
#  'wordpress',
#  'php',
#  'javascript',
#  'jquery',
#  'mysql',
#  'adobe',
#  'photoshop',
#  'figma',
#  'frontend',
#  'spa',
#  'single',
#  'page',
#  'application',
#  'javascript',
#  'html',
#  'css',
#  'photoshop',
#  'figma',
#  'js',
#  'vuejs',
#  'vuex',
#  'react',
#  'angular',
#  'http',
#  'websocket',
#  'rest',
#  'api',
#  'mysql',
#  'php',
#  'cms',
#  'git',
#  'bitbucket',
#  'cms',
#  'joomla',
#  'wordpress',
#  'drupal',
#  'dle',
#  'cms',
#  'opencart',
#  'cms',
#  'php',
#  'gt',
#  'yii',
#  'mysql',
#  'having',
#  'join',
#  'memcached',
#  'redis',
#  'html',
#  'css',
#  'js',
#  'bootstrap',
#  'jquery',
#  'sass',
#  'webpack',
#  'gulp',
#  'vuejs',
#  'nuxtjs',
#  'unix',
#  'nginx',
#  'unit',
#  'git',
#  'docker',
#  'jira',
#  'confluence',
#  'backend',
#  'modx',
#  'revolution',
#  'modx',
#  'php',
#  'mvc',
#  'curl',
#  'json',
#  'mysql',
#  'join',
#  'redis',
#  'cron',
#  'frontend',
#  'html',
#  'css',
#  'bootstrap',
#  'grid',
#  'javascript',
#  'jquery',
#  'ajax',
#  'api',
#  'laravel',
#  'symfony',
#  'yii',
#  'web',
#  'php',
#  'php',
#  'javascript',
#  'jquery',
#  'ajax',
#  'framework',
#  'websocket',
#  'sql',
#  'mysql',
#  'html',
#  'css',
#  'bootstrap',
#  'modx',
#  'codeigniter',
#  'wp',
#  'php',
#  'joomla',
#  'vuejs',
#  'frontend',
#  'react',
#  'redux',
#  'javascript',
#  'mysql',
#  'c',
#  'net',
#  'entity',
#  'frameworkadonet',
#  'drydiekisssolidyagni',
#  'ms',
#  'sql',
#  'tsql',
#  'web',
#  'frontend',
#  'javascript',
#  'eses',
#  'typescript',
#  'html',
#  'css',
#  'sass',
#  'spa',
#  'framework',
#  'vuegsvuex',
#  'webpack',
#  'backend',
#  'api',
#  'git',
#  'phpjavascript',
#  'bootstrap',
#  'jquery',
#  'php',
#  'php',
#  'symfony',
#  'laravel',
#  'nodejs',
#  'sql',
#  'postgresql',
#  'linux',
#  'debian',
#  'centos',
#  'htmlcssjavascriptjquery',
#  'git',
#  'php',
#  'yii',
#  'laravel',
#  'javascript',
#  'jquery',
#  'mysql',
#  'left',
#  'join',
#  'html',
#  'css',
#  'linux',
#  'git',
#  'jira',
#  'js',
#  'css',
#  'html',
#  'ajax',
#  'javascript',
#  'jquery',
#  'backend',
#  'api',
#  'php',
#  'mysql',
#  'json',
#  'ui',
#  'ux',
#  'magento',
#  'php',
#  'mysql',
#  'apache',
#  'nginx',
#  'javascript',
#  'html',
#  'css',
#  'xml',
#  'nix',
#  'adobe',
#  'photoshop',
#  'php',
#  'mvc',
#  'mysql',
#  'linux',
#  'git',
#  'composer',
#  'html',
#  'css',
#  'js',
#  'jquery',
#  'cms',
#  'api',
#  'd',
#  'orm',
#  'result_modifier',
#  'component_epilog',
#  'php',
#  'x',
#  'mysql',
#  'html',
#  'css',
#  'js',
#  'jquery',
#  'ajax',
#  'git',
#  'java',
#  'core',
#  'javascript',
#  'cssless',
#  'unit',
#  'php',
#  'laravel',
#  'sql',
#  'mysql',
#  'jscsshtml',
#  'git',
#  'gitflow',
#  'unixlinux',
#  'bash',
#  'php',
#  'html',
#  'css',
#  'js',
#  'javascript',
#  'vcs',
#  'cms',
#  'bitrix',
#  'javascript',
#  'python',
#  'x',
#  'nodejs',
#  'jquery',
#  'vuejs',
#  'angular',
#  'angularjs',
#  'html',
#  'css',
#  'git',
#  'webpack',
#  'babel',
#  'socket',
#  'io',
#  'mysql',
#  'sqlite',
#  'python',
#  'flask',
#  'django',
#  'unittest',
#  'pytest',
#  'sql',
#  'web',
#  'php',
#  'x',
#  'symfony',
#  'yii',
#  'laravel',
#  'yii',
#  'mysql',
#  'postgresql',
#  'unit',
#  'cicd',
#  'php',
#  'javascript',
#  'git',
#  'html',
#  'css',
#  'sass',
#  'php',
#  'framework',
#  'yii',
#  'docker',
#  'cms',
#  'html',
#  'css',
#  'http',
#  'ftp',
#  'ssh',
#  'js',
#  'php',
#  'php',
#  'laravel',
#  'yii',
#  'mysql',
#  'nodejs',
#  'react',
#  'vue',
#  'git',
#  'nginx',
#  'full',
#  'front',
#  'back',
#  'html',
#  'css',
#  'javascript',
#  'php',
#  'cms',
#  'wordpress',
#  'python',
#  'django',
#  'celery',
#  'flask',
#  'postgresql',
#  'swagger',
#  'django',
#  'orm',
#  'nginx',
#  'git',
#  'linux',
#  'frontend',
#  'd',
#  'orm',
#  'html',
#  'js',
#  'jquery',
#  'ajax',
#  'linux',
#  'javascript',
#  'spa',
#  'reactjs',
#  'svg',
#  'canvasd',
#  'webgl',
#  'http',
#  'json',
#  'js',
#  'php',
#  'laravel',
#  'mysql',
#  'javascript',
#  'es',
#  'jquery',
#  'vuejs',
#  'git',
#  'html',
#  'css',
#  'sass',
#  'docker',
#  'laravel',
#  'php',
#  'javascript',
#  'html',
#  'css',
#  'mysql',
#  'google',
#  'tagmanager',
#  'phpjava',
#  'orm',
#  'mvc',
#  'soa',
#  'postgresqlmysqlfirebird',
#  'http',
#  'rest',
#  'api',
#  'htmlcssjavascriptajaxjqueryangularyiinodejssql',
#  'nodejs',
#  'backend',
#  'devops',
#  'javascript',
#  'es',
#  'es',
#  'html',
#  'css',
#  'nodejs',
#  'vuejs',
#  'react',
#  'angular',
#  'webpack',
#  'babel',
#  'web',
#  'api',
#  'soap',
#  'rest',
#  'websocket',
#  'api',
#  'git',
#  'svn',
#  'mvc',
#  'design',
#  'patterns',
#  'typescript',
#  'less',
#  'scss',
#  'sass',
#  'module',
#  'bundlers',
#  'webpack',
#  'parcel',
#  'browserify',
#  'rollup',
#  'fusebox',
#  'npm',
#  'yarn',
#  'builders',
#  'and',
#  'task',
#  'runners',
#  'grunt',
#  'gulp',
#  'virtualbox',
#  'vargant',
#  'docker',
#  'c',
#  'mongodb',
#  'redis',
#  'cassandra',
#  'neoj',
#  'linux',
#  'ruby',
#  'python',
#  'java',
#  'bash',
#  'perl',
#  'php',
#  'cc',
#  'html',
#  'css',
#  'javascript',
#  'sql',
#  'er',
#  'mysql',
#  'frontend',
#  'react',
#  'js',
#  'backend',
#  'python',
#  'amp',
#  'django',
#  'python',
#  'http',
#  'ssl',
#  'tls',
#  'php',
#  'html',
#  'css',
#  'javascript',
#  'sql',
#  'seo',
#  'html',
#  'css',
#  'javascript',
#  'jquery',
#  'css',
#  'sass',
#  'bem',
#  'class',
#  'names',
#  'gulp',
#  'php',
#  'mysql',
#  'ajax',
#  'Web',
#  'Development',
#  'Cascading',
#  'Style',
#  'Sheets',
#  'CCS',
#  'Html5',
#  'JavaScript',
#  'Responsive',
#  'Web',
#  'Design',
#  'Bootstrap',
#  'Front-End',
#  'Framework',
#  'Node.Js',
#  'React',
#  'Javascript',
#  'Library',
#  'Redux',
#  'Css',
#  'Code',
#  'Html',
#  'JavaScript',
#  'Cascading',
#  'Style',
#  'Sheets',
#  'CCS',
#  'Html',
#  'JavaScript',
#  'Cascading',
#  'Style',
#  'Sheets',
#  'CCS',
#  'Html5',
#  'HTML/CSS',
#  'Mongodb',
#  'Meteor',
#  'APIs',
#  'JavaScript',
#  'Bootstrap',
#  'Front-End',
#  'Framework',
#  'Ionic',
#  'Mobile',
#  'App',
#  'Framework',
#  'Node.Js',
#  'Angularjs',
#  'Hypertext',
#  'Preprocessor',
#  'PHP',
#  'Html',
#  'Cascading',
#  'Style',
#  'Sheets',
#  'CCS',
#  'Mongodb',
#  'Ruby',
#  'On',
#  'Rails',
#  'Angularjs',
#  'Html',
#  'JavaScript',
#  'Css',
#  'Frameworks',
#  'Cascading',
#  'Style',
#  'Sheets',
#  'CCS',
#  'Jquery',
#  'Html',
#  'JavaScript',
#  'Cascading',
#  'Style',
#  'Sheets',
#  'CCS',
#  'Jquery',
#  'web',
#  'application',
#  'development',
#  'Hypertext',
#  'Preprocessor',
#  'PHP',
#  'JavaScript',
#  'MySQL',
#  'Web',
#  'Design',
#  'Websites',
#  'Wordpress',
#  'Web',
#  'Development',
#  'Pensamiento',
#  'computacional',
#  'AbstracciÃ³n',
#  'ProgramaciÃ³n',
#  'DiseÃ±o',
#  'de',
#  'software',
#  'Mongodb',
#  'Meteor',
#  'JavaScript',
#  'Routing',
#  'Hypertext',
#  'Preprocessor',
#  'PHP',
#  'Jquery',
#  'JavaScript',
#  'Hypertext',
#  'Transfer',
#  'Protocol',
#  'HTTP',
#  'Servlets',
#  'Cloud',
#  'Services',
#  'Web',
#  'Application',
#  'Java',
#  'Spring',
#  'Framework',
#  'Mongodb',
#  'Meteor',
#  'JavaScript',
#  'Routing',
#  'Codeskulptor',
#  'Python',
#  'Syntax',
#  'And',
#  'Semantics',
#  'Python',
#  'Programming',
#  'Debugging',
#  'Nativescript',
#  'Bootstrap',
#  'Mongodb',
#  'Node.Js',
#  'Angularjs',
#  'Mongodb',
#  'Meteor',
#  'JavaScript',
#  'Web',
#  'Development',
#  'Web',
#  'Design',
#  'Web',
#  'Accessibility',
#  'Html',
#  'Html5',
#  'Bootstrap',
#  'Front-End',
#  'Framework',
#  'Node.Js',
#  'Jquery',
#  'SASS',
#  'Stylesheet',
#  'Language',
#  'Events',
#  'Esports',
#  'Gaming',
#  'Management',
#  'Production',
#  'Ruby',
#  'On',
#  'Rails',
#  'Web',
#  'Application',
#  'Web',
#  'Ruby',
#  'On',
#  'Rails',
#  'JavaScript',
#  'Web',
#  'Unit',
#  'Testing',
#  'JavaScript',
#  'Angularjs',
#  'Web',
#  'Development',
#  'Internet',
#  'Architecture',
#  'Internet',
#  'Internet',
#  'Security',
#  'Internet',
#  'Protocol',
#  'IP',
#  'Suite',
#  'Video',
#  'Game',
#  'Development',
#  'Video',
#  'Game',
#  'Design',
#  'Unity',
#  'User',
#  'Interface',
#  'Game',
#  'Design',
#  'Software',
#  'Testing',
#  'Android',
#  'Software',
#  'Development',
#  'Java',
#  'Programming',
#  'Junit',
#  'Swift',
#  '5',
#  'Application',
#  'development',
#  'AppStore',
#  'Purchases',
#  'Xcode',
#  'iOS',
#  'App',
#  'Development',
#  'Robot',
#  'Control',
#  'Mobile',
#  'Robot',
#  'Robotics',
#  'Robot',
#  'Phpmyadmin',
#  'MySQL',
#  'Relational',
#  'Database',
#  'SQL',
#  'Database',
#  'DBMS',
#  'Heroku',
#  'Java',
#  'Programming',
#  'Material',
#  'Design',
#  'Instagram',
#  'Android',
#  'Studio',
#  'Web',
#  'Design',
#  'Style',
#  'Sheets',
#  'Cascading',
#  'Style',
#  'Sheets',
#  'CCS',
#  'Web',
#  'Development',
#  'Persistence',
#  'iOS',
#  'App',
#  'Development',
#  'Xcode',
#  'Swift',
#  'Programming',
#  'Language',
#  'User',
#  'Interface',
#  'Design',
#  'UI',
#  'Design',
#  'Objective-C',
#  'Swift',
#  'Programming',
#  'Language',
#  'User',
#  'Interface',
#  'Logic',
#  'Programming',
#  'Android',
#  'Studio',
#  'Java',
#  'Programming',
#  'Object-Oriented',
#  'Programming',
#  'OOP',
#  'Authentication',
#  'Node.Js',
#  'Mongodb',
#  'Express.Js',
#  'Node.Js',
#  'Angularjs',
#  'Reactive',
#  'Programming',
#  'Typescript',
#  'Document',
#  'Object',
#  'Model',
#  'DOM',
#  'JavaScript',
#  'Web',
#  'Development',
#  'Hypertext',
#  'Preprocessor',
#  'PHP',
#  'Create,',
#  'Read,',
#  'Update',
#  'And',
#  'Delete',
#  'MySQL',
#  'Ruby',
#  'Programming',
#  'Language',
#  'Ruby',
#  'On',
#  'Rails',
#  'Heroku',
#  'Bootstrap',
#  'Front-End',
#  'Framework',
#  'Responsive',
#  'Web',
#  'Design',
#  'JavaScript',
#  'Cascading',
#  'Style',
#  'Sheets',
#  'CCS',
#  'iOS',
#  'App',
#  'Development',
#  'Syntax',
#  'Computer',
#  'Programming',
#  'Swift',
#  'Programming',
#  'Language',
#  'Responsive',
#  'Web',
#  'Design',
#  'Html',
#  'JavaScript',
#  'Cascading',
#  'Style',
#  'Sheets',
#  'CCS',
#  'Ionic',
#  'Mobile',
#  'App',
#  'Framework',
#  'Apache',
#  'Cordova',
#  'Angularjs',
#  'Mobile',
#  'Application',
#  'Development',
#  'Interfaces',
#  'Java',
#  'Programming',
#  'Object-Oriented',
#  'Programming',
#  'OOP',
#  'Arrays',
#  'Android',
#  'Studio',
#  'Android',
#  'Operating',
#  'System',
#  'Software',
#  'Android',
#  'Software',
#  'Development',
#  'User',
#  'Interface',
#  'iOS',
#  'App',
#  'Development',
#  'Computer',
#  'Programming',
#  'Xcode',
#  'Objective-C',
#  'Computer',
#  'Programming',
#  'Android',
#  'Studio',
#  'Android',
#  'Software',
#  'Development',
#  'Concurrent',
#  'Computing',
#  'Software',
#  'Testing',
#  'Unit',
#  'Testing',
#  'Android',
#  'Software',
#  'Development',
#  'Junit',
#  'Node.Js',
#  'Angularjs',
#  'Typescript',
#  'Mobile',
#  'Application',
#  'Development',
#  'ProgramaciÃ³n',
#  'Software',
#  'Testing',
#  'Heroku',
#  'Mongodb',
#  'Node.Js',
#  '3d',
#  'computer',
#  'graphics',
#  'Android',
#  'Studio',
#  '2d',
#  'computer',
#  'graphics',
#  'Android',
#  'Github',
#  'Android',
#  'Studio',
#  'Android',
#  'Version',
#  'History',
#  'Material',
#  'Design',
#  'Persistence',
#  'iOS',
#  'App',
#  'Development',
#  'Core',
#  'Data',
#  'User',
#  'Interface',
#  'Redux',
#  'Typescript',
#  'programaciÃ³n',
#  'front-end',
#  'SPA',
#  'testing',
#  'unitario',
#  'TDD',
#  'Angularjs',
#  'iOS',
#  ...]

# %%
def get_cources(vacancy_link):
    # getting vacancy page
    job_page = requests.get(vacancy_link, headers={'User-Agent': 'Custom'})

    # checking if page is ready to
    # bring us some data, else getting error code
    if job_page.status_code == 200:
        # parsing vacancy page using Beautiful Soup
        job_soup = BeautifulSoup(job_page.text, 'html.parser')

        # getting vacancy page content
        page_content = job_soup.find('div', {'class': 'g-user-content'})
        
        # getting splitted page content
        splitted_page_content = re.split('<strong>', str(page_content).lower())

        # initializing flags witch note if 
        # requerments in split
        treb_flag = False
        
        # initializing jobs requerments list
        job_requerments = []
        
        # checking if requerments in the list
        for job_content in splitted_page_content:
            if job_content.startswith('требования'):
                job_requerments.append(job_content)
                treb_flag = True
            
        # if requerments in vacancy, we simply get them
        # and find suitable cources
        if treb_flag != False:
            print('YES')
            item = re.sub('требования', '', job_requerments[0])
            item2 = re.sub('к кандидату', '', item)
            item3 = re.sub('к кандидатам', '', item2)

            # splitting by html tags
            splited_items = re.split(r'<.*?>', item3)

            # initializing list with clean items
            cleared_items = []

            # going through splitted items, cleaning
            # them and adding to cleared items list
            for item in splited_items:
                cleared_items.append(re.sub(r'[^\w\d\s]+', '', re.sub(r'\s+', ' ', re.sub(r'<.*?>', '', item))))

            # deleating all empty items
            while ("" in cleared_items):
                cleared_items.remove("")

            # deleating all space items
            while (" " in cleared_items):
                cleared_items.remove(" ")

            print(cleared_items)
            
            # initializing list for new requerments
            new_req = []


            # initializing temproary requerments list
            temp_req = []

            # going through single requerment and cleaning it
            for string in cleared_items:
                # cleaning requerments
                new_string = re.sub(r'[1-9]+', '', re.sub('ё', '', re.sub(r'\s+', ' ', re.sub(r'[а-я]+', '', string))))
                new_s = re.sub(r'\s+', ' ', new_string)

                # adding single requerment to temproary lsit
                temp_req.append(new_s)

            # adding temproary requerments list to 
            # new requerments list
            new_req.append(temp_req)

            # deleating all space items
            for item in new_req:
                while (" " in item):
                    item.remove(" ")
                    
            # initializing list with cleared requrments
            cleared_reqs = []
                    
            for i in new_req[0]:
                temp_item = i.split()
                for j in temp_item:
                    cleared_reqs.append(j)
            
            print(cleared_reqs)
            
            # initializing cources list
            cources_list = []
            
            # going through requerments and finding cources
            for req in cleared_reqs:
                for (cources_skilles, link) in \
                    zip(cources_data_without_nones['skilles'], cources_data_without_nones['links']):
                    if re.search(req, (''.join(cources_skilles)).lower()):
                        cources_list.append(link)
            
            return cources_list
        
        else:
            print('No requerments')
            # clearing vacancy data
            cleared_content = re.sub(r'[^\w\d\s]+', '', re.sub(r'\s+', ' ', re.sub(r'<.*?>', '', str(splitted_page_content))))
            
            # key words set
            key_words = set()
            
            # getting possibles requerments
            for word in new_web_development_keywords:
                if re.search(word, cleared_content):
                    if len(word) < 3:
                        continue
                    else:
                        key_words.add(word)
                    
            print(key_words)
            
            # initializing cources list
            cources_list = []
            
            # going through requerments and finding cources
            for req in key_words:
                for (cources_skilles, link) in \
                    zip(cources_data_without_nones['skilles'], cources_data_without_nones['links']):
                    if re.search(req, (''.join(cources_skilles)).lower()):
                        cources_list.append(link)
            
            return cources_list
    else:
        print("Something wrong with the page: ", job_page.status_code)
        print('vacancy problem')

# %%
links = get_cources('https://spb.hh.ru/vacancy/35471010?query=%D0%B2%D0%B5%D0%B1%20%D1%80%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%87%D0%B8%D0%BA')
# Out:
# No requerments
# {'css', 'reactjs', 'react', 'python', 'php', 'cassandra', 'ssl', 'javascript', 'dle', 'and', 'sql', 'less', 'java', 'cssless', 'mysql', 'scss', 'mongodb', 'laravel'}

# %%
links
# Out:
# ['https://www.coursera.org/learn/web-development',
#  'https://www.coursera.org/specializations/website-development',
#  'https://www.coursera.org/learn/html-css-javascript-for-web-developers',
#  'https://www.coursera.org/specializations/full-stack-react',
#  'https://www.coursera.org/learn/angular',
#  'https://www.coursera.org/learn/python-programming',
#  'https://www.coursera.org/learn/web-applications-php',
#  'https://www.coursera.org/specializations/web-applications',
#  'https://www.coursera.org/learn/javascript-jquery-json',
#  'https://www.coursera.org/learn/intro-sql',
#  'https://www.coursera.org/learn/database-applications-php',
#  'https://www.coursera.org/specializations/web-design',
#  'https://www.coursera.org/specializations/full-stack-react',
#  'https://www.coursera.org/learn/web-development',
#  'https://www.coursera.org/learn/duke-programming-web',
#  'https://www.coursera.org/specializations/website-development',
#  'https://www.coursera.org/learn/html-css-javascript-for-web-developers',
#  'https://www.coursera.org/learn/website-coding',
#  'https://www.coursera.org/specializations/web-applications',
#  'https://www.coursera.org/learn/meteor-development',
#  'https://www.coursera.org/learn/javascript-jquery-json',
#  'https://www.coursera.org/learn/web-application-development',
#  'https://www.coursera.org/learn/responsive-web-design-capstone',
#  'https://www.coursera.org/learn/aplicaciones-web',
#  'https://www.coursera.org/learn/single-page-web-apps-with-angularjs',
#  'https://www.coursera.org/learn/javascript',
#  'https://www.coursera.org/learn/responsivedesign',
#  'https://www.coursera.org/learn/responsive-web-design',
#  'https://www.coursera.org/learn/web-design-project',
#  'https://www.coursera.org/specializations/java-programming',
#  'https://www.coursera.org/learn/python-programming',
#  'https://www.coursera.org/specializations/android-app-development',
#  'https://www.coursera.org/specializations/programacion-android',
#  'https://www.coursera.org/learn/java-for-android',
#  'https://www.coursera.org/learn/database-applications-php',
#  'https://www.coursera.org/learn/android-programming',
#  'https://www.coursera.org/learn/androidapps',
#  'https://www.coursera.org/learn/engineeringandroidapps',
#  'https://www.coursera.org/learn/intro-android-graphics',
#  'https://www.coursera.org/learn/fundamentos',
#  'https://www.coursera.org/learn/desarrollo-de-aplicaciones',
#  'https://www.coursera.org/learn/android-graphics-opengl-es',
#  'https://www.coursera.org/learn/android-programming-2',
#  'https://www.coursera.org/learn/3d-graphics-android-sensors-vr',
#  'https://www.coursera.org/specializations/web-applications',
#  'https://www.coursera.org/learn/intro-sql',
#  'https://www.coursera.org/learn/database-applications-php',
#  'https://www.coursera.org/specializations/web-design',
#  'https://www.coursera.org/specializations/full-stack-react',
#  'https://www.coursera.org/learn/web-development',
#  'https://www.coursera.org/learn/duke-programming-web',
#  'https://www.coursera.org/specializations/website-development',
#  'https://www.coursera.org/learn/html-css-javascript-for-web-developers',
#  'https://www.coursera.org/learn/website-coding',
#  'https://www.coursera.org/specializations/web-applications',
#  'https://www.coursera.org/learn/meteor-development',
#  'https://www.coursera.org/learn/javascript-jquery-json',
#  'https://www.coursera.org/learn/cloud-services-java-spring-framework',
#  'https://www.coursera.org/learn/web-application-development',
#  'https://www.coursera.org/learn/responsive-web-design-capstone',
#  'https://www.coursera.org/learn/aplicaciones-web',
#  'https://www.coursera.org/learn/single-page-web-apps-with-angularjs',
#  'https://www.coursera.org/specializations/android-app-development',
#  'https://www.coursera.org/specializations/programacion-android',
#  'https://www.coursera.org/learn/java-for-android',
#  'https://www.coursera.org/learn/javascript',
#  'https://www.coursera.org/learn/responsivedesign',
#  'https://www.coursera.org/learn/responsive-web-design',
#  'https://www.coursera.org/learn/programandoconjava',
#  'https://www.coursera.org/learn/web-design-project',
#  'https://www.coursera.org/specializations/java-programming',
#  'https://www.coursera.org/specializations/web-applications',
#  'https://www.coursera.org/learn/intro-sql',
#  'https://www.coursera.org/learn/database-applications-php',
#  'https://www.coursera.org/specializations/website-development',
#  'https://www.coursera.org/specializations/ruby-on-rails',
#  'https://www.coursera.org/learn/meteor-development',
#  'https://www.coursera.org/learn/web-application-development',
#  'https://www.coursera.org/specializations/fullstack-web-development-espanol',
#  'https://www.coursera.org/learn/responsive-web-design-capstone',
#  'https://www.coursera.org/learn/server-side-nodejs',
#  'https://www.coursera.org/learn/desarrollo-lado-servidor-nodejs-express-mongodb']

# %%
links2 = get_cources('https://spb.hh.ru/vacancy/35564260?query=%D0%B2%D0%B5%D0%B1%20%D1%80%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%87%D0%B8%D0%BA')
# Out:
# No requerments
# {'react', 'typescript', 'webpack', 'web', 'bootstrap', 'vuex', 'less', 'css', 'api', 'git', 'angular', 'vuejs', 'rest', 'reactjs', 'javascript', 'java', 'vue', 'html', 'scss'}

# %%
links2
# Out:
# ['https://www.coursera.org/specializations/full-stack-react',
#  'https://www.coursera.org/learn/angular',
#  'https://www.coursera.org/learn/angular',
#  'https://www.coursera.org/learn/nativescript',
#  'https://www.coursera.org/learn/desarrollar-paginas-web-con-angular',
#  'https://www.coursera.org/specializations/web-design',
#  'https://www.coursera.org/specializations/web-applications',
#  'https://www.coursera.org/learn/how-to-create-a-website',
#  'https://www.coursera.org/learn/cloud-services-java-spring-framework',
#  'https://www.coursera.org/learn/responsive-web-design-capstone',
#  'https://www.coursera.org/learn/html',
#  'https://www.coursera.org/learn/web-app',
#  'https://www.coursera.org/learn/aplicaciones-web',
#  'https://www.coursera.org/learn/single-page-web-apps-with-angularjs',
#  'https://www.coursera.org/learn/introcss',
#  'https://www.coursera.org/learn/javascript',
#  'https://www.coursera.org/learn/responsivedesign',
#  'https://www.coursera.org/learn/responsive-web-design',
#  'https://www.coursera.org/learn/web-design-project',
#  'https://www.coursera.org/learn/photo-tourist-web-app-capstone',
#  'https://www.coursera.org/specializations/full-stack-react',
#  'https://www.coursera.org/specializations/full-stack-mobile-app-development',
#  'https://www.coursera.org/specializations/fullstack-web-development-espanol',
#  'https://www.coursera.org/learn/bootstrap-4',
#  'https://www.coursera.org/learn/responsivedesign',
#  'https://www.coursera.org/learn/web-development',
#  'https://www.coursera.org/specializations/website-development',
#  'https://www.coursera.org/learn/html-css-javascript-for-web-developers',
#  'https://www.coursera.org/specializations/website-development',
#  'https://www.coursera.org/learn/fundamentos',
#  'https://www.coursera.org/specializations/full-stack-mobile-app-development',
#  'https://www.coursera.org/specializations/ruby-on-rails',
#  'https://www.coursera.org/specializations/fullstack-web-development-espanol',
#  'https://www.coursera.org/learn/single-page-web-apps-with-angularjs',
#  'https://www.coursera.org/learn/angular',
#  'https://www.coursera.org/learn/ionic-cordova',
#  'https://www.coursera.org/learn/nativescript',
#  'https://www.coursera.org/learn/desarrollar-paginas-web-con-angular',
#  'https://www.coursera.org/learn/aplicaciones-mobile-multiplataforma-nativescript-angular-redux',
#  'https://www.coursera.org/learn/photo-tourist-web-app-capstone',
#  'https://www.coursera.org/specializations/web-design',
#  'https://www.coursera.org/specializations/full-stack-react',
#  'https://www.coursera.org/learn/web-development',
#  'https://www.coursera.org/learn/duke-programming-web',
#  'https://www.coursera.org/specializations/website-development',
#  'https://www.coursera.org/learn/html-css-javascript-for-web-developers',
#  'https://www.coursera.org/learn/website-coding',
#  'https://www.coursera.org/specializations/web-applications',
#  'https://www.coursera.org/learn/meteor-development',
#  'https://www.coursera.org/learn/javascript-jquery-json',
#  'https://www.coursera.org/learn/web-application-development',
#  'https://www.coursera.org/learn/responsive-web-design-capstone',
#  'https://www.coursera.org/learn/aplicaciones-web',
#  'https://www.coursera.org/learn/single-page-web-apps-with-angularjs',
#  'https://www.coursera.org/learn/javascript',
#  'https://www.coursera.org/learn/responsivedesign',
#  'https://www.coursera.org/learn/responsive-web-design',
#  'https://www.coursera.org/learn/web-design-project',
#  'https://www.coursera.org/specializations/java-programming',
#  'https://www.coursera.org/specializations/web-design',
#  'https://www.coursera.org/specializations/full-stack-react',
#  'https://www.coursera.org/learn/web-development',
#  'https://www.coursera.org/learn/duke-programming-web',
#  'https://www.coursera.org/specializations/website-development',
#  'https://www.coursera.org/learn/html-css-javascript-for-web-developers',
#  'https://www.coursera.org/learn/website-coding',
#  'https://www.coursera.org/specializations/web-applications',
#  'https://www.coursera.org/learn/meteor-development',
#  'https://www.coursera.org/learn/javascript-jquery-json',
#  'https://www.coursera.org/learn/cloud-services-java-spring-framework',
#  'https://www.coursera.org/learn/web-application-development',
#  'https://www.coursera.org/learn/responsive-web-design-capstone',
#  'https://www.coursera.org/learn/aplicaciones-web',
#  'https://www.coursera.org/learn/single-page-web-apps-with-angularjs',
#  'https://www.coursera.org/specializations/android-app-development',
#  'https://www.coursera.org/specializations/programacion-android',
#  'https://www.coursera.org/learn/java-for-android',
#  'https://www.coursera.org/learn/javascript',
#  'https://www.coursera.org/learn/responsivedesign',
#  'https://www.coursera.org/learn/responsive-web-design',
#  'https://www.coursera.org/learn/programandoconjava',
#  'https://www.coursera.org/learn/web-design-project',
#  'https://www.coursera.org/specializations/java-programming',
#  'https://www.coursera.org/specializations/web-design',
#  'https://www.coursera.org/learn/web-development',
#  'https://www.coursera.org/learn/duke-programming-web',
#  'https://www.coursera.org/specializations/website-development',
#  'https://www.coursera.org/learn/web-applications-php',
#  'https://www.coursera.org/learn/html-css-javascript-for-web-developers',
#  'https://www.coursera.org/learn/website-coding',
#  'https://www.coursera.org/learn/html',
#  'https://www.coursera.org/learn/responsive-web-design',
#  'https://www.coursera.org/learn/web-design-project',
#  'https://www.coursera.org/specializations/java-programming']
