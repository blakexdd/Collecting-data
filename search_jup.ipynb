# %%
#!/usr/bin/env python
# coding: utf-8

import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import re

# initializing lists with information about job
jobs_content = []  # list with page content about job
jobs_names = []  # list with names of the jobs
jobs_links = []  # list with links to the job page
all_jobs_links = [] # list of all jobs links

# job we want to take
job = 'Веб-разработчик'

# going through all pages at hh.ru site and collecting links that
# refer to job variable and also get content from them
for page_number in range(2):
    # creating link for our job and current page
    jobs_page = 'https://spb.hh.ru/search/vacancy?area=2&st=searchVacancy&text=' + job.lower() + '&page=' + str(
        page_number)

    # getting current hh.ru page with our job
    page = requests.get(jobs_page, headers={'User-Agent': 'Custom'})
    
    # clearing jobs links list
    jobs_links.clear()

    # cheking if page is ready to
    # bring us some data, else getting error code
    if page.status_code == 200:
        # parsing page using Beautiful soup
        soup = BeautifulSoup(page.text, 'html.parser')

        # forming vacancies list from link that
        # refer to partucular vacancy
        vacancies_list = soup.find_all('a', {'class': 'bloko-link HH-LinkModifier'})

        # cheking if vacancies list is not empty
        # and if so, getting vacancy name
        # and vacancy link, then retrieve data from vacancy page
        if len(vacancies_list) > 0:
            # collecting links and names of vacancies
            for vacancy in vacancies_list:
                jobs_names.append(vacancy.text)
                if vacancy['href']:
                    jobs_links.append(vacancy['href'])
                    all_jobs_links.append(vacancy['href'])
                else:
                    print('No job link')
                    jobs_links.append(None)

            # getting page content for each vacancy
            for link in jobs_links:
                # getting vacancy page
                job_page = requests.get(link, headers={'User-Agent': 'Custom'})

                # checking if page is ready to
                # bring us some data, else getting error code
                if job_page.status_code == 200:
                    # parsing vacancy page using Beautiful Soup
                    job_soup = BeautifulSoup(job_page.text, 'html.parser')

                    # getting vacancy page content
                    page_content = job_soup.find('div', {'class': 'g-user-content'})

                    # forming jobs content list
                    jobs_content.append(page_content)
                else:
                    print("Something wrong with the page: ", job_page.status_code)
        else:
            print('No items in vacancies_list')
    else:
        print('Something wrong with page: ', page.status_code)

# initializing list with all data about vacancies
data_list = []

# going through jobs contents and splitting it
# by <strong>. So we get all important headings
# and will be able to get requesments, conditions
# and responsibilities
for job_content in jobs_content:
    data_list.append(re.split('<strong>', str(job_content).lower()))

# initializing lists with information about vacancy
jobs_treb = []  # list of vacancy requerments
jobs_usl = []  # list of vancy conditions
jobs_obyaz = []  # list of vacancy responsibilities
jobs_desc = []  # list of vacancy desctiption

# going through splitted data and getting
# requerments, conditions, responsibilities
# and descriptions
for job in data_list:
    # getting descriptiong because
    # it is always first in the split
    jobs_desc.append(job[0])

    # initializing flags witch note if there is
    # one of requesments, conditions and responsibilities
    # in the split
    treb_flag = False
    obyaz_flag = False
    usl_flag = False

    # checking if there is one of three conditions
    # in our split and if so, adding this conditions
    # to corresponding lists
    for job_content in job:
        if job_content.startswith('требования'):
            jobs_treb.append(job_content)
            treb_flag = True

        if job_content.startswith('обязанности'):
            jobs_obyaz.append(job_content)
            obyaz_flag = True

        if job_content.startswith('условия'):
            jobs_usl.append(job_content)
            usl_flag = True

    # if we haven't found any conditions
    # we add None item to corresponding list
    if treb_flag == False:
        jobs_treb.append(None)

    if obyaz_flag == False:
        jobs_obyaz.append(None)

    if usl_flag == False:
        jobs_usl.append(None)

# initializing lists with clean data about requerments, conditions
# and responsibilities
new_jobs_treb = []  # list of vacancy requerments
new_jobs_obyaz = []  # list of vacancy responsibilities
new_jobs_usl = []  # list of vacancy conditions


# Cleaning informations funcition
# Arguments:
#  Data we want to clean and list where we want
# .  to put this data
# . (data, data_list)
#  Returns:
# .  None
def clear_data(data, data_list):
    # going through the data and firstly cleaning
    # out of three possible conditions, then split
    # out data by html tags to form list or conditions
    # and cleanign data out of usless symbols
    for elem in data:
        if elem != None:
            # cleaning of three conditions
            item = re.sub('требования', '', elem)
            item2 = re.sub('к кандидату', '', item)
            item3 = re.sub('к кандидатам', '', item2)
            item4 = re.sub('условия', '', item3)
            item5 = re.sub('обязанности', '', item4)

            # splitting by html tags
            splited_items = re.split(r'<.*?>', item5)

            # initializing list with clean items
            cleared_items = []

            # going through splitted items, cleaning
            # them and adding to cleared items list
            for item in splited_items:
                cleared_items.append(re.sub(r'[^\w\d\s]+', '', re.sub(r'\s+', ' ', re.sub(r'<.*?>', '', item))))

            # deleating all empty items
            while ("" in cleared_items):
                cleared_items.remove("")

            # deleating all space items
            while (" " in cleared_items):
                cleared_items.remove(" ")

            # adding cleaned items to data_list
            data_list.append(cleared_items)
        else:
            # if no element in data, adding None
            data_list.append(None)


# claning information
clear_data(jobs_obyaz, new_jobs_obyaz)
clear_data(jobs_usl, new_jobs_usl)
clear_data(jobs_treb, new_jobs_treb)

# initializing list for cleaned
# description data
new_jobs_desc = []

# going through all descriptions
# and cleaning it
for desc in jobs_desc:
    # if something in descriotion, cleaning
    # it, overwise, adding None
    if desc != None:
        item = re.sub(r'[^\w\d\s]+', '', re.sub(r'\s+', ' ', re.sub(r'<.*?>', '', desc)))
        new_jobs_desc.append(item)
    else:
        new_jobs_desc.append(None)

# forming DataFrame from retrieved data
web_data = pd.DataFrame({'description': new_jobs_desc, 'requerments': new_jobs_treb, 'conditions': new_jobs_usl,
                         'responsibilities': new_jobs_obyaz, 'links': all_jobs_links})

# initializing lists of courses information
courses_links = []  # list of courses links
courses_skills = []  # list of courses skills
page_links = [] # links to cources on current page

# going through all pages of current job we want to take
# and getting information about skilles we want to aquire
for page in range(1, 13):
    # forming link to courcera pages with job courses we want
    courses_link = 'https://www.coursera.org/search?query=web%20development&indices%5Bprod_all_products_term_optimization%5D%5Bpage%5D=' + str(
        page) + '&indices%5Bprod_all_products_term_optimization%5D%5Bconfigure%5D%5BclickAnalytics%5D=true&indices%5Bprod_all_products_term_optimization%5D%5Bconfigure%5D%5BruleContexts%5D%5B0%5D=ru&indices%5Bprod_all_products_term_optimization%5D%5Bconfigure%5D%5BhitsPerPage%5D=10&configure%5BclickAnalytics%5D=true'

    # getting current page
    page = requests.get(courses_link, headers={'User-Agent': 'Custom'})

    # cheking if page is ready to
    # bring us some data, else getting error code
    if page.status_code == 200:
        # parsing page using Beautiful Soup
        soup = BeautifulSoup(page.text, 'html.parser')

        # getting all courses links at current page
        courses_list = soup.find_all('a', {'data-click-key': 'search.search.click.search_card'})

        # checking if there are courses link on
        # the page and if so, adding links to links list
        # getting course page and retrieving skilles
        if len(courses_list) > 0:
            # clearing page links list
            page_links.clear()
            
            # going through courses and forming links
            for course in courses_list:
                # adding links to links list
                courses_links.append('https://www.coursera.org' + course['href'])
                page_links.append('https://www.coursera.org' + course['href'])

            # going through links and getting pages and skilles
            for link in page_links:
                # getting course page
                course_page = requests.get(link, headers={'User-Agent': 'Custom'})

                # cheking if page is ready to
                # bring us some data, else getting error code
                if course_page.status_code == 200:
                    # parsing page using Beautiful Soup
                    course_soup = BeautifulSoup(course_page.text, 'html.parser')

                    # getting all acquired skilles from course page
                    acquired_skilles = course_soup.find_all('div', {'class': 'Skills border-a p-x-2 p-t-1 p-b-2 m-y-2'})
                    # adding skilles to skilles list
                    courses_skills.append(acquired_skilles)
                else:
                    print("Something wrong with page: ", course_page.status_code)

        else:
            print('No items in courses_list')
    else:
        print('Something wrong with page: ', page.status_code)

# initializing list of cleaned courses skilles
new_courses_skilles = []

# going through all courses skills and
# forming list of skills for each course
for course in courses_skills:
    # checking if something in courses list
    # and if so, getting it
    if len(course) > 0:
        # initializing list with skills
        # for current cource
        temp_skilles = []

        # getting all skilles for current course
        # forming temp_skilles list and adding it
        # to new_courses_skilles
        for skill in range(len(course[0].find_all('span', {'class': 'centerContent_dqfu5r'}))):
            temp_skilles.append(course[0].find_all('span', {'class': 'centerContent_dqfu5r'})[skill].text)
        new_courses_skilles.append(temp_skilles)
    else:
        new_courses_skilles.append(None)

# %%
# getting data where requerments are not null
web_data_with_full_req = web_data[web_data['requerments'].notnull()]

# %%
# setting to display all records in jupyter notebook
# with a scrollbar
pd.set_option('display.max_columns', 150)
pd.set_option('display.width', 1000)
web_data_with_full_req
# Out:
#                                           description                                        requerments                                         conditions                                   responsibilities                                              links
# 0   мы ищем full stack разработчика на наш новый п...  [высшее техническое образование, опыт разработ...                                               None  [разработка серверного программного обеспечени...  https://spb.hh.ru/vacancy/35554864?query=%D0%B...
# 1   наша компания инвестирует в собственные интерн...  [ хорошие знания html5 css3 jsjquery как миним...  [ никакого общения с клиентами,  своевременные...  [ вёрстка страниц для сайтов на основе psd мак...  https://spb.hh.ru/vacancy/35208588?query=%D0%B...
# 2   web программист  htmlверстальщик  вебразработч...  [знание html css jquery php mysql, опыт разраб...  [работа в молодом профессиональном коллективе,...                    [верстка сайтов, вебразработка]  https://spb.hh.ru/vacancy/35204472?query=%D0%B...
# 3                                                      [высшее техническое образование, опыт разработ...                                               None  [разработка frontend и backend новой функциона...  https://spb.hh.ru/vacancy/35347870?query=%D0%B...
# 4   компания starliner разработчик itрешений для б...  [php 7 профессиональное владение ооп опыт прое...                                               None                                               None  https://spb.hh.ru/vacancy/35510248?query=%D0%B...
# 78                                                     [python 3  опыт разработки от 2х лет, django c...  [официальная заработная плата  хорошие премии ...                                               None  https://spb.hh.ru/vacancy/35592282?query=%D0%B...
# 80                                                     [ опыт разработки на 1сбитрикс от 2х лет,  уве...  [ длительное сотрудничество предполагающее пос...  [ поддержание имеющегося функционала сайта ада...  https://spb.hh.ru/vacancy/35036827?query=%D0%B...
# 82  в нашу международную команду требуется талантл...  [опыт программирования на php от трех лет, опы...  [ работы, работа в офисе полная занятость, дос...  [ и функции, fullstack программирование, подде...  https://spb.hh.ru/vacancy/35579971?query=%D0%B...
# 83  вы хороший знаток laravel со знаниями верстки ...  [хорошие знания laravel, знание основных языко...  [совмещение с основной работой, заработная пла...  [доработка и разработка новых плагинов агригат...  https://spb.hh.ru/vacancy/35610230?query=%D0%B...
# 85                                                     [опыт работы программистом не менее 3 лет, зна...  [рабочий день 9001800 пятидневка, конкурентосп...  [разработка webприложений участие в масштабных...  https://spb.hh.ru/vacancy/35436924?query=%D0%B...
# 86  крупнейшая федеральная служба доставки блюд яп...  [1 опыт разработки с использованием nodejs от ...  [конкурентная зп по результатам собеседования,...                                               None  https://spb.hh.ru/vacancy/34613329?query=%D0%B...
# 87                                                     [обязательно, умение разрабатывать на javascri...  [оформление по тк рф, белая заработная плата о...  [разработка программного обеспечения на сторон...  https://spb.hh.ru/vacancy/35332950?query=%D0%B...
# 88                                                     [опыт работы от 3х лет, опыт работы с сайтами ...                                  [график работы  ]  [поддержка сайта на cms bitrix, frontend и bac...  https://spb.hh.ru/vacancy/35479530?query=%D0%B...
# 89  данная работа нацелена на студентов и начинающ...  [хорошее владение html5 css3 javascript, поним...  [вы будете единственным веб разработчиком на п...                                               None  https://spb.hh.ru/vacancy/35391047?query=%D0%B...
# 90                                                     [хорошие навыки html5 css3 javascript jquery, ...  [5дневная рабочая неделя 10001900 пт 1800 обед...  [интеграция верстка с cms, верстка посадочных ...  https://spb.hh.ru/vacancy/35448295?query=%D0%B...
# 92  ищем javascriptпрограммиста с опытом работы с ...  [знание javascript, опыт разработки spa с помо...  [интересные задачи в молодом и дружном коллект...  [проектирование и разработка самостоятельно и ...  https://spb.hh.ru/vacancy/35282792?query=%D0%B...
# 93                                                     [ опыт работы с php,  опыт работы с symfony,  ...  [ полное оформление по тк рф,  возможности ваш...  [ разработка webfrontend с использованием js и...  https://spb.hh.ru/vacancy/34200930?query=%D0%B...
# 95                                                     [опыт создания сайтов на wordpress в т ч умени...  [фиксированный оклад, полный рабочий день с 10...  [разработка лендингов и многостраничных сайтов...  https://spb.hh.ru/vacancy/35415319?query=%D0%B...

# %%
# forming cources data with skilles and link to cources
cources_data = pd.DataFrame({'skilles': new_courses_skilles, 'links': courses_links})

# getting data where skills are not null
cources_data_without_nones = cources_data[cources_data['skilles'].notnull()]

# %%
# Out:
# ['Web Development',
#  'Cascading Style Sheets (CCS)',
#  'Html5',
#  'JavaScript',
#  'Responsive Web Design']

# %%
# Out:
# 'php 7 '

# %%
# initializing list for new requerments
new_requerments = []

# going through old requerments and extracting
# only valuable information
for req in web_data_with_full_req['requerments']:
    # initializing temproary requerments list
    temp_req = []
    
    # going through single requerment and cleaning it
    for string in req:
        # cleaning requerments
        new_string = re.sub(r'[1-9]+', '', re.sub('ё', '', re.sub(r'\s+', ' ', re.sub(r'[а-я]+', '', string))))
        new_s = re.sub(r'\s+', ' ', new_string)
        
        # adding single requerment to temproary lsit
        temp_req.append(new_s)
    
    # adding temproary requerments list to 
    # new requerments list
    new_requerments.append(temp_req)

# deleating all space items
for item in new_requerments:
    while (" " in item):
        item.remove(" ")

# %%
# initializing requerments list
# where all key words are splitted
update_requerments = []

# going through all requerments and
# splitting them by space
for req in new_requerments:
    # initializing temproary list for single string
    temp = []
    
    # going through single string and splitting it
    # by space
    for i in req:
        splited_req = i.split()
        
        # adding splitted requerments to temp list
        temp.append(splited_req)
    
    # adding splitted items to updated requerments list
    update_requerments.append(temp)

# %%
update_requerments
# Out:
# [[['javascriptnodejs'], ['html', 'css'], ['svn', 'git']],
#  [['html', 'css', 'jsjquery', 'lesssass'],
#   ['stylus'],
#   ['wordpress'],
#   ['bem'],
#   ['gulp']],
#  [['html', 'css', 'jquery', 'php', 'mysql'],
#   ['perfect', 'pixel'],
#   ['cms', 'opencart', 'wordpress', 'webasyst']],
#  [['php'],
#   ['ms', 'sql', 'server', '0'],
#   ['freebsdlinux'],
#   ['javascript'],
#   ['sencha'],
#   ['reactjs'],
#   ['spa'],
#   ['npm', 'git', 'webpack', 'html', 'css'],
#   ['nodejs']],
#  [['php'],
#   ['mysqlx'],
#   ['javascript', 'jquery'],
#   ['htmlcss'],
#   ['svn', 'git'],
#   ['xml', 'php', 'soap', 'rest'],
#   ['npm', 'composer'],
#   ['unit', 'phpunit', 'codeception'],
#   ['mongodb', 'redis', 'elastic', 'search']],
#  [['cms', 'wordpress'], ['php', 'html', 'css', 'js'], ['git']],
#  [['php'], ['sql', 'mysql'], ['jscsshtml']],
#  [['frontend'],
#   ['javascript', 'es'],
#   ['css'],
#   ['frontend', 'reactangularvue'],
#   ['backend'],
#   ['net', 'core', 'net', 'framework']],
#  [['php', 'mysql'], ['csshtml', 'js'], ['http']],
#  [['html', 'css'],
#   ['cms', 'joomla', 'bitrix', 'umi', 'wordpress'],
#   ['php', 'javascript', 'jquery', 'mysql'],
#   ['adobe', 'photoshop', 'figma']],
#  [['frontend', 'spa', 'single', 'page', 'application'],
#   ['javascript', 'html', 'css'],
#   ['photoshop', 'figma'],
#   ['js', 'vuejs', 'vuex', 'react', 'angular'],
#   ['http', 'websocket', 'rest', 'api', 'mysql', 'php'],
#   ['cms', 'git', 'bitbucket'],
#   ['cms', 'joomla', 'wordpress', 'drupal', 'dle', 'cms', 'opencart', 'cms']],
#  [['php', 'gt'],
#   ['yii'],
#   ['mysql', 'having', 'join'],
#   ['memcached', 'redis'],
#   ['html', 'css', 'js'],
#   ['bootstrap', 'jquery'],
#   ['sass', 'webpack', 'gulp'],
#   ['vuejs', 'nuxtjs'],
#   ['unix'],
#   ['nginx'],
#   ['unit'],
#   ['git'],
#   ['docker'],
#   ['jira'],
#   ['confluence']],
#  [['backend'],
#   ['modx', 'revolution'],
#   ['modx'],
#   ['php'],
#   ['mvc'],
#   [],
#   ['curl', 'json'],
#   ['mysql'],
#   ['join'],
#   ['redis', 'cron'],
#   ['frontend'],
#   ['html', 'css'],
#   ['bootstrap', 'grid'],
#   ['javascript'],
#   ['jquery', 'ajax'],
#   ['api'],
#   ['laravel', 'symfony', 'yii']],
#  [['web']],
#  [['web'], ['cms', 'bitrix', 'css', 'js', 'html', 'json']],
#  [['php', 'mysqlmariadb', 'html', 'css', 'javascript', 'jquery'], ['git']],
#  [['php'], ['joomla'], ['vuejs']],
#  [['frontend', 'react', 'redux'], ['javascript'], ['mysql']],
#  [['phpjavascript'], ['bootstrap', 'jquery']],
#  [['web', 'frontend'],
#   ['javascript', 'eses', 'typescript'],
#   ['html', 'css', 'sass'],
#   ['spa', 'framework', 'vuegsvuex'],
#   ['webpack'],
#   ['backend', 'api'],
#   ['git']],
#  [['php', 'yii', 'laravel'],
#   ['javascript', 'jquery', 'mysql', 'left', 'join', 'html', 'css'],
#   ['linux'],
#   ['git', 'jira']],
#  [['cms'],
#   ['api', 'd', 'orm'],
#   ['result_modifier', 'component_epilog'],
#   ['php', 'x', 'mysql', 'html', 'css', 'js', 'jquery', 'ajax'],
#   ['git']],
#  [['magento'],
#   ['php', 'mysql', 'apache', 'nginx', 'javascript', 'html', 'css', 'xml'],
#   ['nix'],
#   ['adobe', 'photoshop']],
#  [['java', 'core'], ['javascript'], ['cssless'], ['unit']],
#  [['php'],
#   ['laravel'],
#   ['sql', 'mysql'],
#   ['jscsshtml'],
#   ['git', 'gitflow'],
#   ['unixlinux', 'bash']],
#  [['php', 'html', 'css', 'js', 'javascript', 'vcs'], ['cms', 'bitrix']],
#  [['javascript'],
#   ['python', 'x'],
#   ['nodejs'],
#   ['jquery'],
#   ['vuejs'],
#   ['angular'],
#   ['angularjs'],
#   ['html'],
#   ['css'],
#   ['git'],
#   ['webpack'],
#   ['babel'],
#   ['socket', 'io'],
#   ['mysql'],
#   ['sqlite']],
#  [],
#  [['python'], ['flask', 'django'], ['unittest', 'pytest'], ['sql']],
#  [],
#  [['web'],
#   ['php', 'x'],
#   ['symfony', 'yii', 'laravel'],
#   ['yii'],
#   ['mysql', 'postgresql'],
#   ['unit'],
#   ['cicd']],
#  [['php'],
#   ['javascript'],
#   ['git'],
#   ['html', 'css', 'sass'],
#   ['php', 'framework', 'yii'],
#   ['docker'],
#   ['cms']],
#  [['html', 'css'], ['http', 'ftp', 'ssh'], ['js'], ['php']],
#  [['c', 'net'],
#   ['entity', 'frameworkadonet'],
#   ['drydiekisssolidyagni'],
#   ['ms', 'sql', 'tsql']],
#  [['php', 'laravel', 'yii', 'mysql', 'nodejs', 'react', 'vue', 'git', 'nginx'],
#   ['full', 'front', 'back']],
#  [['html', 'css', 'javascript'], ['php'], ['cms', 'wordpress']],
#  [['python'],
#   ['django', 'celery', 'flask'],
#   ['postgresql'],
#   ['swagger', 'django', 'orm'],
#   ['nginx'],
#   ['git'],
#   ['linux'],
#   ['frontend']],
#  [['d', 'orm'], ['html', 'js', 'jquery', 'ajax'], ['linux']],
#  [['php'],
#   ['laravel'],
#   ['mysql'],
#   ['javascript', 'es', 'jquery', 'vuejs'],
#   ['git'],
#   ['html', 'css', 'sass'],
#   ['docker']],
#  [['laravel'],
#   ['php', 'javascript', 'html', 'css', 'mysql'],
#   ['google', 'tagmanager']],
#  [['phpjava'],
#   ['orm', 'mvc', 'soa'],
#   ['postgresqlmysqlfirebird'],
#   ['http', 'rest', 'api'],
#   ['htmlcssjavascriptajaxjqueryangularyiinodejssql']],
#  [['nodejs'], ['backend'], ['devops']],
#  [[],
#   ['javascript', 'es', 'es'],
#   ['html', 'css'],
#   ['nodejs'],
#   ['vuejs', 'react', 'angular'],
#   ['webpack', 'babel'],
#   ['web', 'api', 'soap', 'rest', 'websocket', 'api'],
#   ['git', 'svn'],
#   ['mvc', 'design', 'patterns'],
#   ['typescript', 'less', 'scss', 'sass'],
#   ['module',
#    'bundlers',
#    'webpack',
#    'parcel',
#    'browserify',
#    'rollup',
#    'fusebox'],
#   ['npm', 'yarn'],
#   ['builders', 'and', 'task', 'runners', 'grunt', 'gulp'],
#   ['virtualbox', 'vargant', 'docker'],
#   ['c', 'mongodb', 'redis', 'cassandra', 'neoj'],
#   ['linux'],
#   ['ruby', 'python', 'java', 'bash', 'perl', 'php', 'cc'],
#   [],
#   []],
#  [['php', 'html', 'css', 'javascript', 'sql'], ['seo']],
#  [['html', 'css', 'javascript'],
#   ['sql', 'er', 'mysql'],
#   ['frontend', 'react', 'js'],
#   ['backend', 'python', 'amp', 'django', 'python'],
#   ['http', 'ssl', 'tls']],
#  [['html', 'css', 'javascript', 'jquery'],
#   ['css', 'sass', 'bem', 'class', 'names', 'gulp'],
#   ['php', 'mysql', 'ajax']],
#  [['javascript'],
#   ['spa', 'reactjs'],
#   ['svg', 'canvasd', 'webgl'],
#   ['http', 'json'],
#   ['js']],
#  [['php'],
#   ['symfony'],
#   ['mvc'],
#   ['git'],
#   ['js'],
#   ['web'],
#   ['web', 'react', 'angular']],
#  [['wordpress']]]

# %%
# updating vacancies list with cleaned requerments
web_data_with_full_req['cleaned requerments'] = update_requerments
# Out:
# /var/data/python/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
web_data_with_full_req
# Out:
#                                           description                                        requerments                                         conditions                                   responsibilities                                              links                                cleaned requerments
# 0   мы ищем full stack разработчика на наш новый п...  [высшее техническое образование, опыт разработ...                                               None  [разработка серверного программного обеспечени...  https://spb.hh.ru/vacancy/35554864?query=%D0%B...      [[javascriptnodejs], [html, css], [svn, git]]
# 83  вы хороший знаток laravel со знаниями верстки ...  [хорошие знания laravel, знание основных языко...  [совмещение с основной работой, заработная пла...  [доработка и разработка новых плагинов агригат...  https://spb.hh.ru/vacancy/35610230?query=%D0%B...  [[laravel], [php, javascript, html, css, mysql...
# 85                                                     [опыт работы программистом не менее 3 лет, зна...  [рабочий день 9001800 пятидневка, конкурентосп...  [разработка webприложений участие в масштабных...  https://spb.hh.ru/vacancy/35436924?query=%D0%B...  [[phpjava], [orm, mvc, soa], [postgresqlmysqlf...
# 86  крупнейшая федеральная служба доставки блюд яп...  [1 опыт разработки с использованием nodejs от ...  [конкурентная зп по результатам собеседования,...                                               None  https://spb.hh.ru/vacancy/34613329?query=%D0%B...                    [[nodejs], [backend], [devops]]
# 87                                                     [обязательно, умение разрабатывать на javascri...  [оформление по тк рф, белая заработная плата о...  [разработка программного обеспечения на сторон...  https://spb.hh.ru/vacancy/35332950?query=%D0%B...  [[], [javascript, es, es], [html, css], [nodej...
# 88                                                     [опыт работы от 3х лет, опыт работы с сайтами ...                                  [график работы  ]  [поддержка сайта на cms bitrix, frontend и bac...  https://spb.hh.ru/vacancy/35479530?query=%D0%B...         [[php, html, css, javascript, sql], [seo]]
# 89  данная работа нацелена на студентов и начинающ...  [хорошее владение html5 css3 javascript, поним...  [вы будете единственным веб разработчиком на п...                                               None  https://spb.hh.ru/vacancy/35391047?query=%D0%B...  [[html, css, javascript], [sql, er, mysql], [f...
# 90                                                     [хорошие навыки html5 css3 javascript jquery, ...  [5дневная рабочая неделя 10001900 пт 1800 обед...  [интеграция верстка с cms, верстка посадочных ...  https://spb.hh.ru/vacancy/35448295?query=%D0%B...  [[html, css, javascript, jquery], [css, sass, ...
# 92  ищем javascriptпрограммиста с опытом работы с ...  [знание javascript, опыт разработки spa с помо...  [интересные задачи в молодом и дружном коллект...  [проектирование и разработка самостоятельно и ...  https://spb.hh.ru/vacancy/35282792?query=%D0%B...  [[javascript], [spa, reactjs], [svg, canvasd, ...
# 93                                                     [ опыт работы с php,  опыт работы с symfony,  ...  [ полное оформление по тк рф,  возможности ваш...  [ разработка webfrontend с использованием js и...  https://spb.hh.ru/vacancy/34200930?query=%D0%B...  [[php], [symfony], [mvc], [git], [js], [web], ...
# 95                                                     [опыт создания сайтов на wordpress в т ч умени...  [фиксированный оклад, полный рабочий день с 10...  [разработка лендингов и многостраничных сайтов...  https://spb.hh.ru/vacancy/35415319?query=%D0%B...                                      [[wordpress]]

# %%
cources_data_without_nones
# Out:
#                                                skilles                                              links
# 0    [Web Development, Cascading Style Sheets (CCS)...  https://www.coursera.org/specializations/web-d...
# 1    [Bootstrap (Front-End Framework), Node.Js, Rea...  https://www.coursera.org/specializations/full-...
# 2    [Css Code, Html, JavaScript, Cascading Style S...     https://www.coursera.org/learn/web-development
# 3    [Html, JavaScript, Cascading Style Sheets (CCS...  https://www.coursera.org/learn/duke-programmin...
# 4        [HTML/CSS, Mongodb, Meteor, APIs, JavaScript]  https://www.coursera.org/specializations/websi...
# 5    [Bootstrap (Front-End Framework), Ionic (Mobil...  https://www.coursera.org/specializations/full-...
# 7    [Hypertext Preprocessor (PHP), Html, Cascading...  https://www.coursera.org/learn/web-application...
# 8                  [Mongodb, Ruby On Rails, Angularjs]  https://www.coursera.org/specializations/ruby-...
# 9    [Html, JavaScript, Css Frameworks, Cascading S...  https://www.coursera.org/learn/html-css-javasc...
# 11   [Jquery, Html, JavaScript, Cascading Style She...      https://www.coursera.org/learn/website-coding
# 12   [Jquery, web application development, Hypertex...  https://www.coursera.org/specializations/web-a...
# 16   [Web Design, Websites, Wordpress, Web Developm...  https://www.coursera.org/learn/how-to-create-a...
# 17   [Pensamiento computacional, AbstracciÃ³n, Prog...  https://www.coursera.org/learn/introduccion-pr...
# 18              [Mongodb, Meteor, JavaScript, Routing]  https://www.coursera.org/learn/meteor-development
# 20   [Hypertext Preprocessor (PHP), Jquery, JavaScr...  https://www.coursera.org/learn/javascript-jque...
# 21   [Hypertext Transfer Protocol (HTTP), Servlets,...  https://www.coursera.org/learn/cloud-services-...
# 22              [Mongodb, Meteor, JavaScript, Routing]  https://www.coursera.org/learn/web-application...
# 23   [Codeskulptor, Python Syntax And Semantics, Py...  https://www.coursera.org/learn/python-programming
# 24   [Nativescript, Bootstrap, Mongodb, Node.Js, An...  https://www.coursera.org/specializations/fulls...
# 25      [Mongodb, Meteor, JavaScript, Web Development]  https://www.coursera.org/learn/responsive-web-...
# 26        [Web Design, Web Accessibility, Html, Html5]                https://www.coursera.org/learn/html
# 27   [Bootstrap (Front-End Framework), Node.Js, Jqu...         https://www.coursera.org/learn/bootstrap-4
# 28   [Events, Esports, Gaming, Management, Production]   https://www.coursera.org/specializations/esports
# 30               [Ruby On Rails, Web Application, Web]             https://www.coursera.org/learn/web-app
# 31                    [Ruby On Rails, JavaScript, Web]    https://www.coursera.org/learn/aplicaciones-web
# 32   [Unit Testing, JavaScript, Angularjs, Web Deve...  https://www.coursera.org/learn/single-page-web...
# 36   [Internet Architecture, Internet, Internet Sec...    https://www.coursera.org/learn/internet-history
# 38   [Video Game Development, Video Game Design, Un...  https://www.coursera.org/specializations/game-...
# 39   [Software Testing, Android Software Developmen...  https://www.coursera.org/specializations/andro...
# 40   [Swift 5, Application development, AppStore Pu...  https://www.coursera.org/specializations/swift...
# 41      [Robot Control, Mobile Robot, Robotics, Robot]        https://www.coursera.org/learn/mobile-robot
# 43       [Phpmyadmin, MySQL, Relational Database, SQL]           https://www.coursera.org/learn/intro-sql
# 45   [Database (DBMS), Heroku, Java Programming, Ma...  https://www.coursera.org/specializations/progr...
# 46   [Persistence, iOS App Development, Xcode, Swif...  https://www.coursera.org/specializations/app-d...
# 47   [Web Design, Style Sheets, Cascading Style She...            https://www.coursera.org/learn/introcss
# 48   [User Interface Design (UI Design), Objective-...  https://www.coursera.org/specializations/ios-d...
# 49   [Logic Programming, Android Studio, Java Progr...    https://www.coursera.org/learn/java-for-android
# 50      [Authentication, Node.Js, Mongodb, Express.Js]  https://www.coursera.org/learn/server-side-nodejs
# 51   [Node.Js, Angularjs, Reactive Programming, Typ...             https://www.coursera.org/learn/angular
# 53   [Document Object Model (DOM), JavaScript, Web ...          https://www.coursera.org/learn/javascript
# 56   [Hypertext Preprocessor (PHP), Create, Read, U...  https://www.coursera.org/learn/database-applic...
# 57   [Ruby (Programming Language), Ruby On Rails, H...  https://www.coursera.org/learn/ruby-on-rails-i...
# 58   [Bootstrap (Front-End Framework), Responsive W...    https://www.coursera.org/learn/responsivedesign
# 60   [iOS App Development, Syntax, Computer Program...   https://www.coursera.org/learn/swift-programming
# 61   [Responsive Web Design, Html, JavaScript, Casc...  https://www.coursera.org/learn/responsive-web-...
# 62   [Interfaces, Java Programming, Object-Oriented...  https://www.coursera.org/learn/programandoconjava
# 63   [Github, Xcode, Apple Watch, Swift (Programmin...  https://www.coursera.org/specializations/desar...
# 64   [Ionic (Mobile App Framework), Apache Cordova,...       https://www.coursera.org/learn/ionic-cordova
# 66   [Android Studio, Android (Operating System) So...  https://www.coursera.org/learn/android-program...
# 68   [iOS App Development, Computer Programming, Xc...         https://www.coursera.org/learn/objective-c
# 71   [Computer Programming, Android Studio, Android...         https://www.coursera.org/learn/androidapps
# 75   [Interaction Technique, List Of Graphical User...  https://www.coursera.org/learn/android-program...
# 76   [Software Testing, Unit Testing, Android Softw...  https://www.coursera.org/learn/engineeringandr...
# 80   [ProgramaciÃ³n, Software Testing, Heroku, Mong...  https://www.coursera.org/learn/desarrollo-lado...
# 81   [3d computer graphics, Android Studio, 2d comp...  https://www.coursera.org/learn/intro-android-g...
# 82   [Github, Android Studio, Android Version Histo...         https://www.coursera.org/learn/fundamentos
# 83   [Persistence, iOS App Development, Core Data, ...  https://www.coursera.org/learn/ios-app-design-...
# 84   [Node.Js, Angularjs, Typescript, Mobile Applic...        https://www.coursera.org/learn/nativescript
# 85   [Redux, Typescript, programaciÃ³n front-end SP...  https://www.coursera.org/learn/desarrollar-pag...
# 89   [iOS App Development, Computer Programming, Xc...  https://www.coursera.org/learn/ios-app-develop...
# 90   [Android Studio, Database (DBMS), Android Soft...  https://www.coursera.org/learn/desarrollo-de-a...
# 91   [iOS App Development, Github, Xcode, Swift (Pr...               https://www.coursera.org/learn/swift
# 92   [Web Design, Html, JavaScript, Cascading Style...  https://www.coursera.org/learn/web-design-project
# 93   [Opengl++, 2d computer graphics, Opengl for Em...  https://www.coursera.org/learn/android-graphic...
# 96   [Nativescript, Desarrollo Mobile Multiplatafor...  https://www.coursera.org/learn/aplicaciones-mo...
# 107  [Opengl++, VR, Sensors, Android Studio, Textures]  https://www.coursera.org/learn/3d-graphics-and...
# 111        [Ruby On Rails, Angularjs, Web Development]  https://www.coursera.org/learn/photo-tourist-w...
# 119  [Html, JavaScript, Cascading Style Sheets (CCS...  https://www.coursera.org/specializations/java-...
